# %%
import random
import numpy as np
import matplotlib.pyplot as plt

ppl = 4
total_cards = np.arange(8, 101, 4)
plot_avg = []

for i in total_cards:
    #---------------
    wincards = [1, 1]
    lose_cards = [0]*(i-2)
    all_cards = wincards + lose_cards

    cards_pp = int(len(all_cards)/ppl)
    times = 10_000

    assert i%4 == 0, '--- not dividable by 4 ---'

    avg_count = []
    for _ in range(10):
        count = 0
        for _ in range(times):
            random.shuffle(all_cards)
            for j in range(ppl):
                if sum(all_cards[j*cards_pp:(j+1)*cards_pp]) == 2:
                    count += 1
        avg_count.append((count/times)*100)
    plot_avg.append(np.mean(avg_count))
    print(f'total card: {i} --- {np.mean(avg_count)}')
plt.plot(plot_avg)
# Out:
# total card: 8 --- 14.193999999999999
# total card: 12 --- 18.136999999999997
# total card: 16 --- 20.035
# total card: 20 --- 21.18
# total card: 24 --- 21.766000000000002
# total card: 28 --- 22.119
# total card: 32 --- 22.699
# total card: 36 --- 22.841
# total card: 40 --- 23.096999999999998
# total card: 44 --- 23.19
# total card: 48 --- 23.266
# total card: 52 --- 23.386
# total card: 56 --- 23.805999999999997
# total card: 60 --- 23.65
# total card: 64 --- 23.682
# total card: 68 --- 23.802999999999997
# total card: 72 --- 23.934
# total card: 76 --- 23.930000000000003
# total card: 80 --- 24.343
# total card: 84 --- 24.156999999999996
# total card: 88 --- 24.331
# total card: 92 --- 24.209999999999997
# total card: 96 --- 24.293
# total card: 100 --- 24.421
